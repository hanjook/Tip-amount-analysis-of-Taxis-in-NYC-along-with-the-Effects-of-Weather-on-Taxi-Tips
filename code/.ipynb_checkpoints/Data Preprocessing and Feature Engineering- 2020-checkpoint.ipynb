# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from numpy import log, sqrt, exp

# apply a log transformation for all x non-zero x points, else 0 
# from Lab 2:
def logify(x):
    return log(x) if x else 0

# %%
# code from lab 2

from numpy import log, log2

def sturges(x):
    return int(log2(x)) + 1

def rice(x):
    return int(2 * x ** (1/3))

def scott(large, small, sd, x):
    return int((large - small) / (3.5 * (sd/x ** (1/3))))

def freedman(large, small, iqr, x):
    return int((large - small) / (2 * (iqr/x ** (1/3))))
    
def square(x):
    return int(sqrt(x))

def logify(x):
    return log(x) if x else 0

# %%
dfy = pd.read_feather('../raw_data/large/yellow-2020.feather').dropna().drop('index', axis=1)

# %%
dfy.shape
# Out:
# (8870830, 19)

# %%
dfy.dtypes
# Out:
# level_0                    int64
# VendorID                 float64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count          float64
# trip_distance            float64
# RatecodeID               float64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type             float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %%
# Some Feature Engineering:

# %%
# Add an extra trip_duration in hours
# Since datetime is an object, convert the datatype to datetime
dfy['tpep_pickup_datetime'] = pd.to_datetime(dfy['tpep_pickup_datetime'])
dfy['tpep_dropoff_datetime'] = pd.to_datetime(dfy['tpep_dropoff_datetime'])
dfy['trip_duration'] = (dfy['tpep_dropoff_datetime'] - dfy['tpep_pickup_datetime']).dt.total_seconds()
dfy['trip_duration'] = dfy['trip_duration']/3600
dfy.head()
# Out:
#    level_0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0        0       1.0  2020-01-01 00:28:15   2020-01-01 00:33:03
# 1        1       1.0  2020-01-01 00:35:39   2020-01-01 00:43:04
# 2        2       1.0  2020-01-01 00:47:41   2020-01-01 00:53:52
# 3        3       1.0  2020-01-01 00:55:23   2020-01-01 01:00:14
# 4        4       2.0  2020-01-01 00:01:58   2020-01-01 00:04:16
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0            1.2         1.0                  N
# 1              1.0            1.2         1.0                  N
# 2              1.0            0.6         1.0                  N
# 3              1.0            0.8         1.0                  N
# 4              1.0            0.0         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           238           239           1.0          6.0    3.0      0.5
# 1           239           238           1.0          7.0    3.0      0.5
# 2           238           238           1.0          6.0    3.0      0.5
# 3           238           151           1.0          5.5    0.5      0.5
# 4           193           193           2.0          3.5    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        1.47           0.0                    0.3         11.27
# 1        1.50           0.0                    0.3         12.30
# 2        1.00           0.0                    0.3         10.80
# 3        1.36           0.0                    0.3          8.16
# 4        0.00           0.0                    0.3          4.80
#
#    congestion_surcharge  trip_duration
# 0                   2.5       0.080000
# 1                   2.5       0.123611
# 2                   2.5       0.103056
# 3                   0.0       0.080833
# 4                   0.0       0.038333

# %%
# trip duration and distance should be positive
# this must be done so that the distributions can be plotted without nan for average_speed
dfy = dfy[(dfy['trip_duration'] > 0)]

# trip distance shouldn't be too large: since nyc area around 302.62687 miles^2

# %%
# add an extra column of average speed of the taxi
dfy['average_speed'] = dfy['trip_distance']/dfy['trip_duration']
dfy.describe()
# Out:
#             level_0      VendorID  passenger_count  trip_distance  \
# count  8.870830e+06  8.870830e+06     8.870830e+06   8.870830e+06
# mean   4.470335e+06  1.665725e+00     1.482799e+00   2.775866e+00
# std    2.606562e+06  4.717365e-01     1.125030e+00   3.363443e+01
# min    0.000000e+00  1.000000e+00     0.000000e+00  -2.218000e+01
# 25%    2.217707e+06  1.000000e+00     1.000000e+00   9.600000e-01
# 50%    4.435414e+06  2.000000e+00     1.000000e+00   1.600000e+00
# 75%    6.738076e+06  2.000000e+00     2.000000e+00   2.880000e+00
# max    9.018630e+06  2.000000e+00     9.000000e+00   9.960311e+04
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  8.870830e+06  8.870830e+06  8.870830e+06  8.870830e+06  8.870830e+06
# mean   1.052494e+00  1.648373e+02  1.623837e+02  1.281476e+00  1.224359e+01
# std    8.161364e-01  6.597036e+01  7.040285e+01  4.832202e-01  3.353772e+02
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00 -1.238000e+03
# 25%    1.000000e+00  1.320000e+02  1.120000e+02  1.000000e+00  6.000000e+00
# 50%    1.000000e+00  1.620000e+02  1.620000e+02  1.000000e+00  9.000000e+00
# 75%    1.000000e+00  2.340000e+02  2.340000e+02  2.000000e+00  1.350000e+01
# max    9.900000e+01  2.650000e+02  2.650000e+02  5.000000e+00  9.983100e+05
#
#               extra       mta_tax    tip_amount  tolls_amount  \
# count  8.870830e+06  8.870830e+06  8.870830e+06  8.870830e+06
# mean   1.083216e+00  4.935675e-01  2.110765e+00  2.870366e-01
# std    1.247459e+00  7.110992e-02  2.662811e+00  1.614268e+00
# min   -2.700000e+01 -5.000000e-01 -9.100000e+01 -3.574000e+01
# 25%    0.000000e+00  5.000000e-01  0.000000e+00  0.000000e+00
# 50%    5.000000e-01  5.000000e-01  1.860000e+00  0.000000e+00
# 75%    2.500000e+00  5.000000e-01  2.850000e+00  0.000000e+00
# max    1.130100e+02  3.080000e+01  1.100000e+03  9.105000e+02
#
#        improvement_surcharge  total_amount  congestion_surcharge  \
# count           8.870830e+06  8.870830e+06          8.870830e+06
# mean            2.976519e-01  1.803565e+01          2.276226e+00
# std             3.663964e-02  3.354729e+02          7.381702e-01
# min            -3.000000e-01 -1.242300e+03         -2.500000e+00
# 25%             3.000000e-01  1.115000e+01          2.500000e+00
# 50%             3.000000e-01  1.415000e+01          2.500000e+00
# 75%             3.000000e-01  1.930000e+01          2.500000e+00
# max             3.000000e-01  9.983256e+05          2.750000e+00
#
#        trip_duration  average_speed
# count   8.870830e+06   8.865063e+06
# mean    2.551263e-01            inf
# std     3.131065e+00            NaN
# min    -8.783400e+03  -2.306412e+01
# 25%     1.019444e-01   8.000000e+00
# 50%     1.675000e-01   1.047817e+01
# 75%     2.683333e-01   1.408696e+01
# max     1.420853e+02            inf

# %%
# Add which day of the week and hour of the day its in

# Monday = 0, Tuesday = 1 ... Sunday = 6
dfy['day'] = dfy['tpep_pickup_datetime'].apply(lambda x: x.weekday())
dfy['hour'] = dfy['tpep_pickup_datetime'].apply(lambda x: x.hour)

# %%
dfy.head()
# Out:
#    level_0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0        0       1.0  2020-01-01 00:28:15   2020-01-01 00:33:03
# 1        1       1.0  2020-01-01 00:35:39   2020-01-01 00:43:04
# 2        2       1.0  2020-01-01 00:47:41   2020-01-01 00:53:52
# 3        3       1.0  2020-01-01 00:55:23   2020-01-01 01:00:14
# 4        4       2.0  2020-01-01 00:01:58   2020-01-01 00:04:16
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0            1.2         1.0                  N
# 1              1.0            1.2         1.0                  N
# 2              1.0            0.6         1.0                  N
# 3              1.0            0.8         1.0                  N
# 4              1.0            0.0         1.0                  N
#
#    PULocationID  DOLocationID  ...  mta_tax  tip_amount  tolls_amount  \
# 0           238           239  ...      0.5        1.47           0.0
# 1           239           238  ...      0.5        1.50           0.0
# 2           238           238  ...      0.5        1.00           0.0
# 3           238           151  ...      0.5        1.36           0.0
# 4           193           193  ...      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  trip_duration  \
# 0                    0.3         11.27                   2.5       0.080000
# 1                    0.3         12.30                   2.5       0.123611
# 2                    0.3         10.80                   2.5       0.103056
# 3                    0.3          8.16                   0.0       0.080833
# 4                    0.3          4.80                   0.0       0.038333
#
#    average_speed  day  hour
# 0      15.000000    2     0
# 1       9.707865    2     0
# 2       5.822102    2     0
# 3       9.896907    2     0
# 4       0.000000    2     0
#
# [5 rows x 23 columns]

# %%
# Prelimnary Analysis of the raw data
N = len(dfy)

sns.distplot(dfy['trip_distance'], bins=30)
plt.title('Density Distribution of Trip Distances')
plt.xlabel('Trip distance (Miles)')
plt.ylabel('Density')
plt.show()

sns.distplot(dfy['trip_duration'], bins=30)
plt.title('Density Distribution of Trip Duration')
plt.xlabel('Trip Duration (Hours)')
plt.ylabel('Density')
plt.show()

sns.distplot(dfy['average_speed'], bins=30)
plt.title('Density Distribution of Average speed of the vehicle')
plt.xlabel('Average Speed (Miles/hour)')
plt.ylabel('Density')
plt.show()

sns.distplot(dfy['fare_amount'], bins=sturges(N))
plt.title('Density Distribution of Fare amounts')
plt.xlabel('Fare Amount ($)')
plt.ylabel('Density')
plt.show()

sns.distplot(dfy['tip_amount'], bins=sturges(N))
plt.title('Density Distribution of Tip amounts')
plt.xlabel('Tip Amount ($)')
plt.ylabel('Density')
plt.show()

sns.countplot(dfy['passenger_count'], color = 'blue')
plt.title('Passenger Count')
plt.xlabel('Number of Passengers')
plt.show()

sns.countplot(dfy['day'], color = 'blue')
plt.title('Number of Taxi Trips per Day in a week')
plt.xlabel('Day of the Week')
plt.show()

sns.countplot(dfy['hour'], color = 'blue')
plt.title('Number of Taxi Trips per Hour in a day')
plt.xlabel('Hour of the Day')
plt.show()

sns.countplot(dfy['payment_type'], color = 'blue')
plt.title('Frequencies of Payment Methods')
plt.xlabel('Payment type')
plt.show()

sns.countplot(dfy['RatecodeID'], color = 'blue')
plt.title('Frequencies of Fare Rates')
plt.xlabel('Fare Type')
plt.show()

# %%
# Prelimnary Analysis of the raw data
N = len(dfy)

sns.distplot(dfy['trip_distance'].apply(logify), bins=30)
plt.title('Proportional Distribution of Trip Distances')
plt.xlabel('Trip distance (Miles)')
plt.ylabel('Proportion')
plt.show()

sns.distplot(dfy['trip_duration'].apply(logify), bins=30)
plt.title('Proportional Distribution of Trip Duration')
plt.xlabel('Trip Duration (Hours)')
plt.ylabel('Proportion')
plt.show()

sns.distplot(dfy['average_speed'].apply(logify), bins=30)
plt.title('Density Distribution of Average speed of the vehicle')
plt.xlabel('Average Speed (Miles/hour)')
plt.ylabel('Density')
plt.show()

sns.distplot(dfy['fare_amount'].apply(logify), bins=sturges(N))
plt.title('Proportional Distribution of Fare amounts')
plt.xlabel('Fare Amount ($)')
plt.ylabel('Proportion')
plt.show()

sns.distplot(dfy['tip_amount'].apply(logify), bins=sturges(N))
plt.title('Proportional Distribution of Tip amounts')
plt.xlabel('Tip Amount ($)')
plt.ylabel('Proportion')
plt.show()

# %%
# Preprocessing starts

# %%
# check if there are variables with nulls
dfy.isnull().sum()
# Out:
# level_0                     0
# VendorID                    0
# tpep_pickup_datetime        0
# tpep_dropoff_datetime       0
# passenger_count             0
# trip_distance               0
# RatecodeID                  0
# store_and_fwd_flag          0
# PULocationID                0
# DOLocationID                0
# payment_type                0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# tolls_amount                0
# improvement_surcharge       0
# total_amount                0
# congestion_surcharge        0
# trip_duration               0
# average_speed            5767
# day                         0
# hour                        0
# dtype: int64

# %%
dfy = dfy[dfy['average_speed'].notnull()]

# %%
# Retain exp(4) for test set as well

preprocessed_df = dfy[(dfy['trip_distance'] > 0) & (dfy['trip_distance'] < exp(4))]

# %%
preprocessed_df.head()
# Out:
#    level_0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0        0       1.0  2020-01-01 00:28:15   2020-01-01 00:33:03
# 1        1       1.0  2020-01-01 00:35:39   2020-01-01 00:43:04
# 2        2       1.0  2020-01-01 00:47:41   2020-01-01 00:53:52
# 3        3       1.0  2020-01-01 00:55:23   2020-01-01 01:00:14
# 4        4       2.0  2020-01-01 00:01:58   2020-01-01 00:04:16
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0            1.2         1.0                  N
# 1              1.0            1.2         1.0                  N
# 2              1.0            0.6         1.0                  N
# 3              1.0            0.8         1.0                  N
# 4              1.0            0.0         1.0                  N
#
#    PULocationID  DOLocationID  ...  mta_tax  tip_amount  tolls_amount  \
# 0           238           239  ...      0.5        1.47           0.0
# 1           239           238  ...      0.5        1.50           0.0
# 2           238           238  ...      0.5        1.00           0.0
# 3           238           151  ...      0.5        1.36           0.0
# 4           193           193  ...      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  trip_duration  \
# 0                    0.3         11.27                   2.5       0.080000
# 1                    0.3         12.30                   2.5       0.123611
# 2                    0.3         10.80                   2.5       0.103056
# 3                    0.3          8.16                   0.0       0.080833
# 4                    0.3          4.80                   0.0       0.038333
#
#    average_speed  day  hour
# 0      15.000000    2     0
# 1       9.707865    2     0
# 2       5.822102    2     0
# 3       9.896907    2     0
# 4       0.000000    2     0
#
# [5 rows x 23 columns]

# %%
# max RatecodeID shouldn't be 99. Max should be 6.
# negative fare amount and other variables regarding money. initial charge is $2.5
# passenger count cannot be 0
# trip distance shouldn't be too large, which may be an outlier. nyc area is 783.8km^2 which is around 302.62687 square miles
# max fare amount being $187439 is an outlier
# Someone tipped $1001!

# %%
preprocessed_df['RatecodeID'].value_counts()
# Out:
# 1.0     8618235
# 2.0      178032
# 5.0       45383
# 3.0       15630
# 4.0        6959
# 99.0        349
# 6.0          57
# Name: RatecodeID, dtype: int64

# %%
# remove ratecodes with 99.0
preprocessed_df = preprocessed_df[(preprocessed_df['RatecodeID'] == 1) | (preprocessed_df['RatecodeID'] == 2)]

preprocessed_df['RatecodeID'].value_counts()
# Out:
# 1.0    8618235
# 2.0     178032
# Name: RatecodeID, dtype: int64

# %%
# check what passenger number is viable
preprocessed_df['passenger_count'].value_counts()
# Out:
# 1.0    6418383
# 2.0    1258803
# 3.0     328630
# 5.0     289717
# 6.0     178568
# 0.0     170741
# 4.0     151417
# 9.0          5
# 7.0          2
# 8.0          1
# Name: passenger_count, dtype: int64

# %%
# Make passengers less than 7 and more than 0
preprocessed_df = preprocessed_df[(preprocessed_df['passenger_count'] < 7) &(preprocessed_df['passenger_count'] > 0)]

# %%
# Fare amount should be more than $2.5
preprocessed_df = preprocessed_df[preprocessed_df['fare_amount'] > 2.5]

# %%
# fare_amount should be less than around exp(5)
preprocessed_df = preprocessed_df[preprocessed_df['fare_amount'] < exp(5)]

# %%
# tip amount should be less than around exp(3)
preprocessed_df = preprocessed_df[preprocessed_df['tip_amount'] < exp(3)]

# %%
preprocessed_df.head()
# Out:
#    level_0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0        0       1.0  2020-01-01 00:28:15   2020-01-01 00:33:03
# 1        1       1.0  2020-01-01 00:35:39   2020-01-01 00:43:04
# 2        2       1.0  2020-01-01 00:47:41   2020-01-01 00:53:52
# 3        3       1.0  2020-01-01 00:55:23   2020-01-01 01:00:14
# 4        4       2.0  2020-01-01 00:01:58   2020-01-01 00:04:16
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0            1.2         1.0                  N
# 1              1.0            1.2         1.0                  N
# 2              1.0            0.6         1.0                  N
# 3              1.0            0.8         1.0                  N
# 4              1.0            0.0         1.0                  N
#
#    PULocationID  DOLocationID  ...  mta_tax  tip_amount  tolls_amount  \
# 0           238           239  ...      0.5        1.47           0.0
# 1           239           238  ...      0.5        1.50           0.0
# 2           238           238  ...      0.5        1.00           0.0
# 3           238           151  ...      0.5        1.36           0.0
# 4           193           193  ...      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  trip_duration  \
# 0                    0.3         11.27                   2.5       0.080000
# 1                    0.3         12.30                   2.5       0.123611
# 2                    0.3         10.80                   2.5       0.103056
# 3                    0.3          8.16                   0.0       0.080833
# 4                    0.3          4.80                   0.0       0.038333
#
#    average_speed  day  hour
# 0      15.000000    2     0
# 1       9.707865    2     0
# 2       5.822102    2     0
# 3       9.896907    2     0
# 4       0.000000    2     0
#
# [5 rows x 23 columns]

# %%
# average speed should be less than around exp(3.75)
preprocessed_df = preprocessed_df[preprocessed_df['average_speed'] < exp(3.75)]

# %%
preprocessed_df['payment_type'].value_counts()
# Out:
# 1.0    6286326
# 2.0    2206846
# 3.0      29173
# 4.0      10985
# Name: payment_type, dtype: int64

# %%
# Delete rows with payment type 3 and 4
preprocessed_df = preprocessed_df[(preprocessed_df['payment_type'] == 1) | (preprocessed_df['payment_type'] == 2)]
preprocessed_df['payment_type'].value_counts()
# Out:
# 1.0    6286326
# 2.0    2206846
# Name: payment_type, dtype: int64

# %%
preprocessed_df['day'].value_counts()
# Out:
# 3    1500550
# 4    1491075
# 2    1378888
# 1    1137691
# 5    1106119
# 0     994783
# 6     884066
# Name: day, dtype: int64

# %%
preprocessed_df['congestion_surcharge'].value_counts()
# Out:
# 2.50    7869594
# 0.00     623431
# 2.75         76
# 0.75         65
# 0.50          5
# 0.80          1
# Name: congestion_surcharge, dtype: int64

# %%
preprocessed_df['mta_tax'].value_counts()
# Out:
# 0.50     8490472
# 0.00        2684
# 3.30           7
# 1.10           4
# 0.35           1
# 30.80          1
# 6.80           1
# 2.80           1
# 1.54           1
# Name: mta_tax, dtype: int64

# %%
preprocessed_df['improvement_surcharge'].value_counts()
# Out:
# 0.3    8491736
# 0.0       1436
# Name: improvement_surcharge, dtype: int64

# %%
# Drop variables deemed unnecessary

preprocessed_df = preprocessed_df.drop('mta_tax', axis = 1);
preprocessed_df = preprocessed_df.drop('congestion_surcharge', axis = 1);
preprocessed_df = preprocessed_df.drop('improvement_surcharge', axis = 1);
preprocessed_df = preprocessed_df.drop('VendorID', axis = 1);
preprocessed_df = preprocessed_df.drop('store_and_fwd_flag', axis = 1);

#get rid of random 'level_0' column
#preprocessed_df = preprocessed_df.drop('level_0', axis = 1);

# %%
preprocessed_df.tail()
# Out:
#          level_0 tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 9018625  9018625  2020-10-31 23:43:30   2020-11-01 00:08:16              1.0
# 9018626  9018626  2020-10-31 23:11:43   2020-10-31 23:15:21              1.0
# 9018628  9018628  2020-10-31 23:30:11   2020-11-01 00:06:20              1.0
# 9018629  9018629  2020-10-31 23:09:36   2020-10-31 23:15:34              2.0
# 9018630  9018630  2020-10-31 23:32:03   2020-10-31 23:41:56              1.0
#
#          trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 9018625           4.37         1.0           114            17           1.0
# 9018626           0.83         1.0           262           236           1.0
# 9018628           7.37         1.0           239            25           1.0
# 9018629           1.35         1.0           262           140           1.0
# 9018630           3.68         1.0           140            79           1.0
#
#          fare_amount  extra  tip_amount  tolls_amount  total_amount  \
# 9018625         19.0    0.5        6.84           0.0         29.64
# 9018626          5.0    0.5        1.20           0.0         10.00
# 9018628         28.5    0.5        8.07           0.0         40.37
# 9018629          6.5    0.5        1.50           0.0         11.80
# 9018630         12.5    0.5        3.00           0.0         19.30
#
#          trip_duration  average_speed  day  hour
# 9018625       0.412778      10.586810    5    23
# 9018626       0.060556      13.706422    5    23
# 9018628       0.602500      12.232365    5    23
# 9018629       0.099444      13.575419    5    23
# 9018630       0.164722      22.340641    5    23

# %%
# Add the weather external dataset

w1 = pd.read_csv("../raw_data/weather/weather_2020-01.csv")
w2 = pd.read_csv("../raw_data/weather/weather_2020-04.csv")
w3 = pd.read_csv("../raw_data/weather/weather_2020-07.csv")
w4 = pd.read_csv("../raw_data/weather/weather_2020-10.csv")
weather = pd.concat([w1,w2,w3,w4]).reset_index()


weather['date'] = pd.to_datetime(weather['date']).dt.date


# Only the average_temp (Fahrenheit) and precipitation (inches) will be used:
weather = weather[['date','avg_temp', 'precipitation']]

print(weather['precipitation'].value_counts())


# Change T (trace of rain) as 0 to categorize it.
weather['precipitation'].replace('T', 0, inplace = True)

# Make it's raining: 1 not raining: 0
rain_level = [0,1]

# Make it's cold: <46, it's not cold >46
temp_level = [0,1]
weather['precipitation'] = weather['precipitation'].astype(float)
weather['precipitation'] = pd.cut(weather['precipitation'], bins=[-float('inf'), 0, float('inf')], labels=rain_level)
weather['avg_temp'] = pd.cut(weather['avg_temp'], bins=[-float('inf'), 46, float('inf')], labels=temp_level)


preprocessed_df['date'] = preprocessed_df['tpep_pickup_datetime'].dt.date
merged_df = pd.merge(preprocessed_df, weather, how = 'left', on = 'date').drop('date', axis =1)
merged_df[merged_df.isna().any(axis=1)]

# We find that dates that are not included in the months e.g there are some december dates. Hence, they are excluded
# using dropna()
# Out:
# 0       62
# T       13
# 0.02     7
# 0.04     3
# 0.13     3
# 0.01     3
# 0.07     3
# 0.03     2
# 0.22     2
# 0.11     2
# 0.15     1
# 0.34     1
# 0.48     1
# 0.18     1
# 0.19     1
# 0.08     1
# 0.2      1
# 1.92     1
# 0.05     1
# 0.78     1
# 0.96     1
# 0.54     1
# 1.36     1
# 0.27     1
# 0.76     1
# 1.42     1
# 0.37     1
# 1.53     1
# 0.64     1
# 0.85     1
# 0.12     1
# 2.54     1
# 0.71     1
# Name: precipitation, dtype: int64
#          level_0 tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 750          796  2019-12-31 23:48:07   2019-12-31 23:53:39              1.0
# 1223        1276  2019-12-31 23:59:40   2020-01-01 00:09:06              2.0
# 1362        1419  2019-12-31 23:56:19   2020-01-01 00:15:43              1.0
# 1782        1846  2019-12-31 21:39:23   2019-12-31 21:47:34              5.0
# 1783        1847  2019-12-31 22:11:41   2019-12-31 22:21:53              5.0
# ...          ...                  ...                   ...              ...
# 8492368  9017795  2020-11-01 00:04:13   2020-11-01 00:22:45              3.0
# 8492386  9017813  2020-11-01 00:00:39   2020-11-01 00:10:18              1.0
# 8492647  9018086  2020-11-01 00:01:30   2020-11-01 00:20:59              1.0
# 8492706  9018147  2020-11-01 00:01:53   2020-11-01 00:08:19              3.0
# 8492845  9018291  2020-11-01 00:00:00   2020-11-01 00:33:30              2.0
#
#          trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 750               0.88         1.0            41            41           2.0
# 1223              2.19         1.0           231           158           1.0
# 1362              3.74         1.0           162           158           1.0
# 1782              2.04         1.0           263            41           1.0
# 1783              2.95         1.0            79           140           1.0
# ...                ...         ...           ...           ...           ...
# 8492368           4.37         1.0            50            79           1.0
# 8492386           1.81         1.0           237           239           1.0
# 8492647           3.63         1.0           229           186           1.0
# 8492706           1.72         1.0           114            68           1.0
# 8492845          17.68         2.0           132           161           1.0
#
#          fare_amount  extra  tip_amount  tolls_amount  total_amount  \
# 750              6.0    0.5        0.00           0.0          7.30
# 1223             9.5    0.5        2.66           0.0         15.96
# 1362            15.0    0.5        5.64           0.0         24.44
# 1782             8.5    0.5        2.46           0.0         14.76
# 1783            10.5    0.5        1.00           0.0         15.30
# ...              ...    ...         ...           ...           ...
# 8492368         15.5    0.5        3.86           0.0         23.16
# 8492386          9.0    0.5        2.56           0.0         15.36
# 8492647         16.5    0.5        4.06           0.0         24.36
# 8492706          7.5    0.5        2.26           0.0         13.56
# 8492845         52.0    0.0       13.82           0.0         69.12
#
#          trip_duration  average_speed  day  hour avg_temp precipitation
# 750           0.092222       9.542169    1    23      NaN           NaN
# 1223          0.157222      13.929329    1    23      NaN           NaN
# 1362          0.323333      11.567010    1    23      NaN           NaN
# 1782          0.136389      14.957230    1    21      NaN           NaN
# 1783          0.170000      17.352941    1    22      NaN           NaN
# ...                ...            ...  ...   ...      ...           ...
# 8492368       0.308889      14.147482    6     0      NaN           NaN
# 8492386       0.160833      11.253886    6     0      NaN           NaN
# 8492647       0.324722      11.178785    6     0      NaN           NaN
# 8492706       0.107222      16.041451    6     0      NaN           NaN
# 8492845       0.558333      31.665672    6     0      NaN           NaN
#
# [355 rows x 20 columns]

# %%
merged_df = merged_df.drop('tpep_pickup_datetime', axis = 1);
merged_df = merged_df.drop('tpep_dropoff_datetime', axis = 1);
merged_df = merged_df.dropna()

# %%
merged_df.shape
# Out:
# (8492817, 18)

# %%
merged_df.reset_index().to_feather('../preprocessed_data/final_yellow-2020.feather')
